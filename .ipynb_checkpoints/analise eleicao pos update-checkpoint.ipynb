# %% [markdown]
# # Análise de evidências de fraude nas urnas.

# %% [markdown]
# Recentemente tomei conhecimento de uma discussão sobre "urnas fraudadas" devido aos diversos casos de urnas estatisticamente absurdas.
#
# 144 urnas possuem 100% de votos para o Lula, enquanto apenas 5 urnas possuem 100% de votos para o Bolsonaro, algo estatisticamente improvável em caso de amostras aleatórias. No entanto, as urnas possuem o viés de localização, pois apenas pessoas que moram em sua zona eleitoral podem votar nessas seções.
#
# Existe também o viés do perfil do eleitor do Bolsonaro e do Lula.
#
# Nesta análise, verificaremos evidências de fraudes nas urnas, baseado em suas zonas eleitorais, perfil dos eleitores e endereços de votação.

# %% [markdown]
# Os dados para análise podem ser obtidos no site do TSE

# %% [markdown]
# link: https://dadosabertos.tse.jus.br/dataset/resultados-2022-boletim-de-urna

# %% [markdown]
# # 1 - Preparo de dados e bibliotecas

# %% [markdown]
# ## 1.1 Funções e bibliotecas

# %%
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import math
import numpy as np
from scipy.stats import norm, binom

# %%
def media_de_votos(df,uf=None, zona = None,  secao = None, municipio = None, local = None):
    df_set = df
    
    if uf:
        df_set = df_set[df_set.SG_UF == uf]
    if municipio:
        df_set = df_set[df_set.NM_MUNICIPIO == municipio]
    if zona:
        df_set = df_set[df_set.NR_ZONA == zona]
    if local:
        df_set = df_set[df_set.DS_LOCAL_VOTACAO_ENDERECO == local]
    if secao:
        df_set = df_set[df_set.NR_SECAO == secao]
    return df_set.BOLSONARO.sum()/df_set.total.sum()

# %%
from matplotlib.ticker import PercentFormatter
import seaborn as sns
plt.rcParams['figure.figsize'] = [11, 7]
sns.set()

def plot_regiao(df,uf=None, zona = None,  secao = None, municipio = None, local = None, normal=False, title = None):
    df_set = df.copy()
    if uf:
        df_set = df_set[df_set.SG_UF == uf]
    if municipio:
        df_set = df_set[df_set.NM_MUNICIPIO == municipio]
    if zona:
        df_set = df_set[df_set.NR_ZONA == zona]
    if local:
        df_set = df_set[df_set.DS_LOCAL_VOTACAO_ENDERECO == local]
    if secao:
        df_set = df_set[df_set.NR_SECAO == secao]
    
    fig, ax = plt.subplots()
    values, bins, _ = plt.hist(df_set.porcentagem, bins = 50, range=[0,1])
    
    if normal:
        area = sum(np.diff(bins)*values)
        mu, std = norm.fit(df_set.porcentagem)
        x = np.linspace(mu - 4*std, mu + 4*std, 100)
        x = x[np.where(x > 0)]
        ax = sns.lineplot(x = x, y = norm.pdf(x, mu, std)*area)
    plt.title(title)
    ax.xaxis.set_major_formatter(PercentFormatter(1.0))
    plt.show()
    plt.clf()

# %%
plot_regiao(df_sel, municipio='ATALAIA DO NORTE', zona = 42, normal=True)

# %%
def print_media_votos(df,uf=None, zona = None,  secao = None, municipio = None):
    df_set = df
    if uf:
        df_set = df_set[df_set.SG_UF == uf]
    if municipio:
        df_set = df_set[df_set.NM_MUNICIPIO == municipio]
    if zona:
        df_set = df_set[df_set.NR_ZONA == zona]
    if secao:
        df_set = df_set[df_set.NR_SECAO == secao]
    print("Média de votos em urnas abaixo de 3 DP = {:.2f}".format(df_set[df_set.abaixo].total.mean()))
    print("Média de votos em urnas restantes = {:.2f}".format(df_set[~df_set.abaixo].total.mean()))

# %%
def contar_secoes(df, municipio, zona):
    df_set = df[(df.NM_MUNICIPIO == municipio) & (df.NR_ZONA == zona)]
    return len(df_set)

# %% [markdown]
# ## 1.2 Preparo de dados

# %% [markdown]
# A base de nossa análise será a porcentagem de votos no Bolsonaro em cada secão eleitoral.

# %%
df_orig = pd.read_csv('votacao_secao_2022_BR.csv', encoding='latin 1', sep = ';')

# %%
# Selecionar apenas colunas relevantes
df_sel = df_orig[df_orig.NR_TURNO == 2][['NR_TURNO','SG_UF','NM_MUNICIPIO','NR_ZONA','NR_SECAO', 'NR_VOTAVEL', 'QT_VOTOS', 'DS_LOCAL_VOTACAO_ENDERECO']].copy()

df_sel['LULA'] = df_sel.apply(lambda s: s.QT_VOTOS if s.NR_VOTAVEL == 13 else 0,axis=1)
df_sel['BOLSONARO'] = df_sel.apply(lambda s: s.QT_VOTOS if s.NR_VOTAVEL == 22 else 0,axis=1)

df_sel = df_sel.groupby(['NR_TURNO','SG_UF','NM_MUNICIPIO','NR_ZONA','NR_SECAO', 'DS_LOCAL_VOTACAO_ENDERECO'], as_index=False)[['LULA','BOLSONARO']].sum()

# %%
# Fazer coluna de total de votos e porcentagem de votos válidos para o Bolsonaro
df_sel['total'] = df_sel['LULA'] + df_sel['BOLSONARO']
df_sel['porcentagem'] = df_sel['BOLSONARO']/df_sel['total']

# %%
# Trazer dados estatisticos de cada endereço e zona eleitoral
enderecos = df_sel.groupby(['SG_UF','NR_ZONA', 'DS_LOCAL_VOTACAO_ENDERECO'], as_index=False)\
            .agg(media_end=('porcentagem','mean'),desv_padrao_end=('porcentagem','std'),
             quantidade_end=('porcentagem','count'))

zonas = df_sel.groupby(['SG_UF','NR_ZONA'], as_index=False)\
            .agg(media_zona=('porcentagem','mean'),desv_padrao_zona=('porcentagem','std'),
             quantidade_zona=('porcentagem','count'))

df_sel = df_sel.merge(enderecos, on=['SG_UF','NR_ZONA','DS_LOCAL_VOTACAO_ENDERECO'], how='left')
df_sel = df_sel.merge(zonas, on=['SG_UF','NR_ZONA'], how='left')

df_sel["z_score_end"] = (df_sel.porcentagem-df_sel.media_end)/df_sel.desv_padrao_end
df_sel["z_score_zona"] = (df_sel.porcentagem-df_sel.media_zona)/df_sel.desv_padrao_zona

# %%
print("Urnas com 0 votos para o Bolsonaro =",len(df_sel[df_sel.BOLSONARO == 0]))
# Out:
# Urnas com 0 votos para o Bolsonaro = 144

# %%
print("Urnas com 0 votos para o Lula =",len(df_sel[df_sel.LULA == 0]))
# Out:
# Urnas com 0 votos para o Lula = 5

# %% [markdown]
# # 2 - Análise exploratória

# %% [markdown]
# ## 2.1 - Viés de urnas com poucos votos

# %% [markdown]
# Urnas com poucos votos possuem alta probabilidade de ter 100% dos votos em um único candidato. Existem, inclusive, 2 urnas com apenas 1 voto computado. Obviamente, em ambas as urnas 100% dos votos estão em uma única pessoa.
#
# Para analisar as urnas mais relevantes, eliminaremos as urnas com menos de 50 votos.

# %%
print(f"Urnas com menos de 50 votos: {len(df_sel[df_sel.total < 50])}")
# Out:
# Urnas com menos de 50 votos: 702

# %%
df_sel_50 = df_sel[df_sel.total >= 50]

# %%
#Calcular numero de votos mantidos
len(df_sel_50)/len(df_sel)
# Out:
# 0.9985128000881304

# %%
#Calcular média de votos para o Bolsonaro antes de remover
media_de_votos(df_sel)
# Out:
# 0.49097594882827844

# %%
#Calcular média de votos para o Bolsonaro depois de remover
media_de_votos(df_sel_50)
# Out:
# 0.49101267075302074

# %% [markdown]
# Ao eliminar as urnas com poucos votos, quase não houve alteração na média dos votos (0.003%).
#
# Prosseguiremos então com a análise entre as urnas com mais de 50 votos.

# %%
print("Urnas com 0 votos para o Bolsonaro =",len(df_sel_50[df_sel_50.BOLSONARO == 0]))
# Out:
# Urnas com 0 votos para o Bolsonaro = 118

# %%
print("Urnas com 0 votos para o Lula =",len(df_sel_50[df_sel_50.LULA == 0]))
# Out:
# Urnas com 0 votos para o Lula = 1

# %% [markdown]
# Ainda há uma discrepância grande entre votos no Lula e no Bolsonaro. Analisaremos agora o viés de localização.

# %% [markdown]
# ## 2.2 - Viés de localização

# %% [markdown]
# ### 2.2.1 - Visão geral

# %% [markdown]
# Um dos possíveis motivos para este viés ocorrer é por existirem regiões remotas com alinhamento político extremo. Caso as urnas estejam acumuladas em uma mesma zona eleitoral, poderemos justificar que a votação é característica da região.
#
# Um ponto importante a verificar é que, caso em um mesmo endereço haja uma diferença muito grande entre as urnas em um mesmo local (por exemplo, urna com 60% de votos para o Bolsonaro e outra com 0%), devemos justificar a existência desta discrepância, ou assumir que as urnas são provavelmente fraudadas.

# %%
# Quantidade de urnas sem votos para o Bolsonaro por estado
df_sel_50[(df_sel_50.BOLSONARO == 0)].groupby('SG_UF')['NM_MUNICIPIO'].count().reset_index(name="Urnas sem votos para Bolsonaro")
# Out:
#    SG_UF  Urnas sem votos para Bolsonaro
# 0     AC                               2
# 1     AM                              22
# 2     BA                              16
# 3     CE                               7
# 4     MA                              42
# 5     MG                               7
# 6     MS                               1
# 7     MT                               5
# 8     PA                               5
# 9     PI                               5
# 10    PR                               1
# 11    RR                               2
# 12    RS                               1
# 13    SP                               1
# 14    TO                               1

# %% [markdown]
# A princípio analizaremos algumas regiões do Amazonas e do Maranhão por serem as regiões com maior número de urnas sem votos para o Bolsonaro.
#
# Após a análise destas duas regiões, faremos uma análise geral de todas as urnas do Brasil.

# %% [markdown]
# ### 2.2.1 Amazonas

# %% [markdown]
# #### 2.2.1.1 - Visão geral

# %% [markdown]
# Primeiramente, verificaremos as regiões com urnas com 0 votos:

# %%
df_sel_50[(df_sel_50.BOLSONARO == 0) & (df_sel_50.SG_UF == 'AM')]
# Out:
#        NR_TURNO SG_UF               NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
#
  porcentagem  media_end  desv_padrao_end  quantidade_end  \
# 8906     138          0.0   0.000000              NaN               1
# 8909     127          0.0   0.000000              NaN               1
# 8910     175          0.0   0.000000              NaN               1
# 8914     107          0.0   0.000000              NaN               1
# 9090     237          0.0   0.001656         0.002341               2
# 9470      91          0.0   0.000000              NaN               1
# 10102     94          0.0   0.016854         0.023835               2
# 15553    196          0.0   0.000000         0.000000               2
# 15557    156          0.0   0.000000         0.000000               2
# 15569    303          0.0   0.003728         0.002412               6
# 15640    239          0.0   0.005582         0.004839               3
# 15652    207          0.0   0.011526         0.007705               8
# 15664    166          0.0   0.003086         0.004365               2
# 15671    135          0.0   0.000000              NaN               1
# 15677    204          0.0   0.000000         0.000000               2
# 15699    162          0.0   0.000000              NaN               1
# 15704    195          0.0   0.000000         0.000000               2
# 15743    277          0.0   0.011998         0.009704               6
# 15761    347          0.0   0.002770         0.003917               2
# 15765    350          0.0   0.017567         0.021907               4
# 15892    146          0.0   0.000000              NaN               1
# 15894    132          0.0   0.021396         0.010875              10
#
#        media_zona  desv_padrao_zona  quantidade_zona  z_score_end  \
# 8906     0.186807          0.128282               29          NaN
# 8909     0.186807          0.128282               29          NaN
# 8910     0.186807          0.128282               29          NaN
# 8914     0.186807          0.128282               29          NaN
# 9090     0.083193          0.040356               61    -0.707107
# 9470     0.205426          0.070010               63          NaN
# 10102    0.455346          0.170454               67    -0.707107
# 15553    0.259727          0.092087               27          NaN
# 15557    0.259727          0.092087               27          NaN
# 15569    0.228546          0.130886               77    -1.545588
# 15640    0.184239          0.141320               97    -1.153610
# 15652    0.184239          0.141320               97    -1.495927
# 15664    0.184239          0.141320               97    -0.707107
# 15671    0.184239          0.141320               97          NaN
# 15677    0.184239          0.141320               97          NaN
# 15699    0.184239          0.141320               97          NaN
# 15704    0.184239          0.141320               97          NaN
# 15743    0.180172          0.127237               75    -1.236496
# 15761    0.180172          0.127237               75    -0.707107
# 15765    0.180172          0.127237               75    -0.801909
# 15892    0.333181          0.186901               98          NaN
# 15894    0.333181          0.186901               98    -1.967390
#
#        z_score_zona
# 8906      -1.456226
# 8909      -1.456226
# 8910      -1.456226
# 8914      -1.456226
# 9090      -2.061509
# 9470      -2.934236
# 10102     -2.671366
# 15553     -2.820441
# 15557     -2.820441
# 15569     -1.746140
# 15640     -1.303701
# 15652     -1.303701
# 15664     -1.303701
# 15671     -1.303701
# 15677     -1.303701
# 15699     -1.303701
# 15704     -1.303701
# 15743     -1.416036
# 15761     -1.416036
# 15765     -1.416036
# 15892     -1.782661
# 15894     -1.782661

# %% [markdown]
# Verificaremos então as três zonas eleitorais com maior número de urnas com 100% dos votos para o Lula. As zonas eleitorais 42, 19 e 22. Estas 3 regiões representam mais da metade das urnas "suspeitas".

# %% [markdown]
# #### 2.2.1.2 - Atalaia do Norte, zona 42

# %%
plot_regiao(df_sel, municipio='ATALAIA DO NORTE', zona = 42, normal=True)

# %% [markdown]
# Apesar de se tratar da mesma região, é evidente que há uma diferença grande entre as urnas, tendo 6 urnas sem votos para o Bolsonaro e uma urna com 60% de votos.
#
# Analisaremos então os endereços desta zona eleitoral.

# %%
print("Urnas com mais de 50% de votos para o Bolsonaro")
df_sel[(df_sel.NR_ZONA == 42) & (df_sel.SG_UF == 'AM') & (df_sel.porcentagem < 0.10)]
# Out:
# Urnas com mais de 50% de votos para o Bolsonaro
#       NR_TURNO SG_UF      NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 8906         2    AM  ATALAIA DO NORTE       42        25
# 8907         2    AM  ATALAIA DO NORTE       42        26
# 8908         2    AM  ATALAIA DO NORTE       42        27
# 8909         2    AM  ATALAIA DO NORTE       42        28
# 8910         2    AM  ATALAIA DO NORTE       42        29
# 8911         2    AM  ATALAIA DO NORTE       42        30
# 8914         2    AM  ATALAIA DO NORTE       42        37
#
#                               DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  \
# 8906  COM. SÃO LUIZ,  ALDEIA INDIGENA, MÉDIO RIO JAVARI   138          0
# 8907          COM. LOBO, ALDEIA INDIGENA, RIO JAQUIRANA   257          1
# 8908     COM. VIDA NOVA, ALDEIA INDIGENA, ALTO RIO ITUÍ   178         19
# 8909  COM. SÃO SEBASTIÃO, ALDEIA INDIGENA, MÉDIO RIO...   127          0
# 8910      COM. REMANSINHO, ALDEIA INDIGENA, RIO ITACOAÍ   175          0
# 8911  COM. PARAISO, ALDEIA INDIGENA, RIO BRANCO, MAR...   107          1
# 8914     COM. MARONAL, ALDEIA INDIGENA, ALTO RIO CURUÇÁ   107          0
#
#       total  porcentagem  media_end  desv_padrao_end  quantidade_end  \
# 8906    138     0.000000   0.000000              NaN               1
# 8907    258     0.003876   0.003876              NaN               1
# 8908    197     0.096447   0.096447              NaN               1
# 8909    127     0.000000   0.000000              NaN               1
# 8910    175     0.000000   0.000000              NaN               1
# 8911    108     0.009259   0.009259              NaN               1
# 8914    107     0.000000   0.000000              NaN               1
#
#       media_zona  desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 8906    0.186807          0.128282               29          NaN     -1.456226
# 8907    0.186807          0.128282               29          NaN     -1.426012
# 8908    0.186807          0.128282               29          NaN     -0.704392
# 8909    0.186807          0.128282               29          NaN     -1.456226
# 8910    0.186807          0.128282               29          NaN     -1.456226
# 8911    0.186807          0.128282               29          NaN     -1.384047
# 8914    0.186807          0.128282               29          NaN     -1.456226

# %%
print("Urnas com mais de 50% de votos para o Bolsonaro")
df_sel[(df_sel.NR_ZONA == 42) & (df_sel.SG_UF == 'AM') & (df_sel.porcentagem > 0.1)]
# Out:
# Urnas com mais de 50% de votos para o Bolsonaro
#       NR_TURNO SG_UF      NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 8886         2    AM  ATALAIA DO NORTE       42         1
# 8887         2    AM  ATALAIA DO NORTE       42         2
# 8888         2    AM  ATALAIA DO NORTE       42         3
# 8889         2    AM  ATALAIA DO NORTE       42         4
# 8890         2    AM  ATALAIA DO NORTE       42         5
# 8891         2    AM  ATALAIA DO NORTE       42         6
# 8892         2    AM  ATALAIA DO NORTE       42         7
# 8893         2    AM  ATALAIA DO NORTE       42         8
# 8894         2    AM  ATALAIA DO NORTE       42         9
# 8895         2    AM  ATALAIA DO NORTE       42        10
# 8896         2    AM  ATALAIA DO NORTE       42        11
# 8897         2    AM  ATALAIA DO NORTE       42        12
# 8898         2    AM  ATALAIA DO NORTE       42        13
# 8899         2    AM  ATALAIA DO NORTE       42        14
# 8900         2    AM  ATALAIA DO NORTE       42        15
# 8901         2    AM  ATALAIA DO NORTE       42        18
# 8902         2    AM  ATALAIA DO NORTE       42        19
# 8903         2    AM  ATALAIA DO NORTE       42        20
# 8904         2    AM  ATALAIA DO NORTE       42        21
# 8905         2    AM  ATALAIA DO NORTE       42        22
# 8912         2    AM  ATALAIA DO NORTE       42        35
# 8913         2    AM  ATALAIA DO NORTE       42        36
#
#                      DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
#
v_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 8886          0.128282               29     0.142239      0.601741
# 8887          0.128282               29     1.607944      0.923765
# 8888          0.128282               29    -0.555177      0.448516
# 8889          0.128282               29    -0.428866      0.110126
# 8890          0.128282               29    -0.639150      0.000845
# 8891          0.128282               29          NaN      3.288758
# 8892          0.128282               29          NaN     -0.671461
# 8893          0.128282               29     0.640088      0.373291
# 8894          0.128282               29     1.268744      0.366059
# 8895          0.128282               29     0.507174      0.334593
# 8896          0.128282               29    -1.110251      0.326563
# 8897          0.128282               29    -0.564458      0.089684
# 8898          0.128282               29    -1.458511      0.250048
# 8899          0.128282               29    -0.630017      0.079800
# 8900          0.128282               29     0.508979      0.682316
# 8901          0.128282               29     0.928201      0.457174
# 8902          0.128282               29     0.216551      0.618068
# 8903          0.128282               29    -1.394152     -0.035402
# 8904          0.128282               29     0.648227      0.712910
# 8905          0.128282               29     0.779230      0.292260
# 8912          0.128282               29    -1.436312     -0.231245
# 8913          0.128282               29     0.969520      0.320948

# %% [markdown]
# A seção com 60% de votos no Bolsonaro está no **pelotão de fronteira estirão do Equador** enquanto as seções com 0 votos estão em aldeias indígenas.
#
# Todas as aldeias indígenas possuem uma média abaixo de 10% de votos no Bolsonaro. Fica evidente que o viés nas urnas são facilmente justificáveis e as amostras não são aleatórias dentro da zona eleitoral.
#
# Vamos checar agora a zona 19, SÃO GABRIEL DA CACHOEIRA.

# %% [markdown]
# #### 2.2.1.3 - São Gabriel da Cachoeira

# %%
print("Número de seções eleitorais:",
      len(df_sel_50[(df_sel_50.NR_ZONA == 19) & 
           (df_sel_50.NM_MUNICIPIO == 'SÃO GABRIEL DA CACHOEIRA') & 
           (df_sel_50.SG_UF == 'AM')]))
# Out:
# Número de seções eleitorais: 97

# %%
plot_regiao(df_sel_50, municipio='SÃO GABRIEL DA CACHOEIRA', zona = 19, normal=True)

# %% [markdown]
# Novamente, a mesma zona eleitoral possui valores discrepantes.

# %%
df_sel_50[(df_sel_50.NR_ZONA == 19) & 
           (df_sel_50.NM_MUNICIPIO == 'SÃO GABRIEL DA CACHOEIRA') & 
           (df_sel_50.SG_UF == 'AM')].value_counts('DS_LOCAL_VOTACAO_ENDERECO')
# Out:
# DS_LOCAL_VOTACAO_ENDERECO
# PRAÇA NÚNCIO APOSTÓLICO DOM SEBASTIÃO BÁGGIO                 20
# RUA QUATRO S/N                                               10
# BR 307, KM 3                                                  9
# COM. IAUARETÊ (DISTRITO),  RIO WAUPÉS                         8
# RUA CRISPINIANO DA SILVA, 169                                 6
# AV. PAU BRASIL S/N                                            5
# COM. FOZ DO IÇANA                                             3
# COM. (DISTRITO) PARI-CACHOEIRA                                3
# COM. MATURACÁ, RIO MATURACÁ AFLUENTE DO RIO CAUBURIS          3
# COM. CANADÁ, RIO AYARI, MARGEM DIREITA                        2
# COM. TUNUÍ, RIO IÇANA                                         2
# COM. TARACUÁ (DISTRITO)                                       2
# COM. SÃO JOAQUIM,  RIO IÇANA                                  2
# COM. BOCA DA ESTRADA, RIO TIQUIÉ, MARGEM ESQUERDA             2
# COM. CUCUÍ (DISTRITO) KM 210                                  2
# COM. DE NAZARÉ, RIO CUBATE, MARGEM ESQUERDA                   1
# COM. CARURU CACHOEIRA, ALTO RIO TIQUIÉ, MARGEM DIREITA        1
# COM. ANAMOIN, RIO XIÉ                                         1
# COM. VILA NOVA,  RIO XIÉ                                      1
# COM. CASTELO BRANCO, RIO IÇANA (MÉDIO), MARGEM ESQUERDA       1
# COM. CORACI, RIO IÇANA (ALTO), MARGEM DIREITA                 1
# COM. TAPURUCUARA MIRIM, RIO NEGRO (BAIXO), MARGEM DIREITA     1
# COM. SÃO LUIZ, RIO NEGRO, MARGEM DIREITA                      1
# COM. SÃO FELIPE, RIO NEGRO, MARGEM DIREITA                    1
# COM. DO BALAIO BR 397 KM 100                                  1
# COM. QUERARI, RIO WAUPÉS                                      1
# COM. CURICURIARI, RIO CURICURIARI, MARGEM DIREITA             1
# COM. LIVRAMENTO, RIO NEGRO (BAIXO), MARGEM ESQUERDA           1
# COM. CUÉ CUÉ, RIO NEGRO (ALTO)                                1
# COM. ILHA DE CAMANAUS, RIO NEGRO                              1
# COM. ARACÚ CACHOEIRA, ALTO RIO IÇANA, MARGEM DIREITA          1
# COM. ASSUNÇÃO DO IÇANA, RIO IÇANA                             1
# COM. JUIVITERA, RIO IÇANA (ALTO), MARGEM DIREITA              1
# dtype: int64

# %% [markdown]
# Em uma análise inicial separaremos as comunidades dos demais endereços.

# %%
regiao_1 = df_sel_50.loc[df_sel_50['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("COM.", case=False) & 
                              (df_sel_50.NR_ZONA == 19) & 
                               (df_sel_50.NM_MUNICIPIO == 'SÃO GABRIEL DA CACHOEIRA')]
regiao_2 = df_sel_50.loc[~df_sel_50['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("COM.", case=False) & 
                              (df_sel_50.NR_ZONA == 19) & 
                               (df_sel_50.NM_MUNICIPIO == 'SÃO GABRIEL DA CACHOEIRA')]

# %%
print("Zonas eleitorais em comunidades de São Gabriel da Cachoeira")
plot_regiao(regiao_1, normal=True)
# Out:
# Zonas eleitorais em comunidades de São Gabriel da Cachoeira

# %%
print("Demais zonas eleitorais de São Gabriel da Cachoeira")
plot_regiao(regiao_2, normal=True)
# Out:
# Demais zonas eleitorais de São Gabriel da Cachoeira

# %% [markdown]
# Novamente, esta simples separação já deixa evidente que existe um viés nos votos em comunidades e fora de comunidades.

# %% [markdown]
# A última zona eleitoral do amazonas que analisaremos é a de SÃO PAULO DE OLIVENÇA.

# %% [markdown]
# #### 2.2.1.4 - São Paulo de Olivença

# %%
plot_regiao(df_sel_50, municipio='SÃO PAULO DE OLIVENÇA', zona = 22, normal=True)

# %%
df_sel_50[(df_sel_50.NR_ZONA == 22) & 
           (df_sel_50.NM_MUNICIPIO == 'SÃO PAULO DE OLIVENÇA') & 
           (df_sel_50.SG_UF == 'AM')].value_counts('DS_LOCAL_VOTACAO_ENDERECO')
# Out:
# DS_LOCAL_VOTACAO_ENDERECO
# RUA MONSENHOR EVANGELISTA, SN                              9
# ESTRADA DO BONFIM, SN                                      7
# COM. CAMPO ALEGRE, RIO SOLIMÕES, MARGEM ESQUERDA           6
# ESTRADA DO AJARATUBA, S/N                                  5
# COM. VENDAVAL, RIO SOLIMÕES, MARGEM ESQUERDA               4
# RUA TRINTA E UM DE MAIO, SN                                4
# AVENIDA BRASIL, SN                                         3
# COM. SANTA RITA DO WEILL, RIO SOLIMÕES, MARGEM ESQUERDA    3
# COM. BOA ESPERANCA, RIO SOLIMÕES, MARGEM ESQUERDA          2
# COM. BOM SUCESSO, RIO CAMATIÃ, MARGEM DIREITA              2
# COM. SANTA INES, RIO SOLIMÕES, MARGEM ESQUERDA             2
# COM. VERA CRUZ, RIO SOLIMÕES, MARGEM DIREITA               2
# COM. BOM JESUS, RIO SOLIMÕES, MARGEM ESQUERDA              1
# COM. DE TUPY II, RIO SOLIMÕES, MARGEM DIREITA              1
# COM. DECUÃPU, RIO CAMATIÃ, MARGEM ESQUERDA                 1
# COM. PARANAPARA, RIO CAMATIÃ, MARGEM DIREITA               1
# dtype: int64

# %% [markdown]
# Novamente, separaremos as comunidades das demais regiões.

# %%
regiao_1 = df_sel_50.loc[df_sel_50['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("COM.", case=False) & 
                              (df_sel_50.NR_ZONA == 22) & 
                               (df_sel_50.NM_MUNICIPIO == 'SÃO PAULO DE OLIVENÇA')]
regiao_2 = df_sel_50.loc[~df_sel_50['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("COM.", case=False) & 
                              (df_sel_50.NR_ZONA == 22) & 
                               (df_sel_50.NM_MUNICIPIO == 'SÃO PAULO DE OLIVENÇA')]

# %%
plot_regiao(regiao_1, normal=True,  title = "Zonas eleitorais em comunidades de São Paulo de Olivença")

# %%
plot_regiao(regiao_2, normal=True, title = "Demais zonas eleitorais de São Paulo de Olivença")

# %% [markdown]
# Com esta simples separação, fica evidente o viés causado por zonas eleitorais dentro/fora de comunidades.
#
# Como as amostras não são aleatórias, o teorema do limite central não se aplica no conjunto total desta zona eleitoral. Não há, portanto, evidências de impossibilidades estatísticas nas urnas analisadas.

# %% [markdown]
# ### 2.2.2 Maranhão

# %% [markdown]
# #### 2.2.2.1 Visão geral

# %%
print("Quantidade de urnas com 0 votos:")
len(df_sel_50[(df_sel_50.BOLSONARO == 0) & (df_sel_50.SG_UF == 'MA')])
# Out:
# Quantidade de urnas com 0 votos:
# 42

# %%
df_sel_50[(df_sel_50.BOLSONARO == 0) & (df_sel_50.SG_UF == 'MA')]
# Out:
#         NR_TURNO SG_UF               NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 106223         2    MA       AMARANTE DO MARANHÃO       99       127
# 107289         2    MA                     BACURI      107        38
# 107505         2    MA             BARRA DO CORDA       23        19
# 107840         2    MA               BARREIRINHAS       56       175
# 107889         2    MA               BARREIRINHAS       56       239
# 108412         2    MA                      BREJO       24       253
# 109089         2    MA                 CARUTAPERA       55        69
# 110539         2    MA                   CURURUPU       14       175
# 110895         2    MA            FERNANDO FALCÃO       97       185
# 110912         2    MA            FERNANDO FALCÃO       97       205
# 110913         2    MA            FERNANDO FALCÃO       97       207
# 111537         2    MA                  GUIMARÃES       30        74
# 111695         2    MA                      ICATU       31       168
# 112334         2    MA         ITAIPAVA DO GRAJAÚ       15       314
# 112496         2    MA            ITAPECURU MIRIM       16       337
# 112887         2    MA              LAGO DO JUNCO       74       295
# 113284         2    MA              MARANHÃOZINHO      101        78
# 113698         2    MA               MONTES ALTOS      103        28
# 113700         2    MA               MONTES ALTOS      103        80
# 114185         2    MA                  PARNARAMA       36        69
# 114825         2    MA           PEDRO DO ROSÁRIO      106        54
# 114895         2    MA                    PENALVA       45        63
# 117123               POVOADO BARRA GRANDE - ZONA RURAL    86          0
# 117225                         POVOADO MATA DO OLIMPIO    87          0
# 121259  PRACA DA IGREJA SN - POVOADO SAO JOSE DO BRITO   148          0
# 121387                                    SÃO DOMINGOS    70          0
# 121392                                        CAJUEIRO    90          0
# 122189                              POVOADO TUCUNZEIRO    73          0
#
#         total  porcentagem  media_end  desv_padrao_end  quantidade_end  \
# 106223     73          0.0   0.141930         0.137808               5
# 107289    106          0.0   0.000000              NaN               1
# 107505     74          0.0   0.000000              NaN               1
# 107840     87          0.0   0.000000              NaN               1
# 107889     51          0.0   0.000000              NaN               1
# 108412     61          0.0   0.000000              NaN               1
# 109089     53          0.0   0.235108         0.195659              21
# 110539     56          0.0   0.000000              NaN               1
# 110895    283          0.0   0.001747         0.002019               4
# 110912    310          0.0   0.001747         0.002019               4
# 110913     69          0.0   0.000000              NaN               1
# 111537    101          0.0   0.000000              NaN               1
# 111695     91          0.0   0.000000              NaN               1
# 112334    277          0.0   0.000000              NaN               1
# 112496     89          0.0   0.000000              NaN               1
# 112887     66          0.0   0.000000              NaN               1
# 113284    307          0.0   0.000000              NaN               1
# 113698    260          0.0   0.221281         0.142010               9
# 113700    264          0.0   0.221281         0.142010               9
# 114185     80          0.0   0.000000              NaN               1
# 114825    204          0.0   0.013986         0.019779               2
# 114895    119          0.0   0.000000              NaN               1
# 115756    130          0.0   0.023810         0.033672               2
# 115781    121          0.0   0.000000              NaN               1
# 115806     93          0.0   0.000000              NaN               1
# 115811     92          0.0   0.000000              NaN               1
# 115844     60          0.0   0.000000              NaN               1
# 116484     56          0.0   0.000000              NaN               1
# 116842     83          0.0   0.057185         0.049789               3
# 116843     98          0.0   0.000000              NaN               1
# 116853    103          0.0   0.000000              NaN               1
# 117020     60          0.0   0.000000              NaN               1
# 117022     68          0.0   0.000000              NaN               1
# 117035     61          0.0   0.000000              NaN               1
# 117096    213          0.0   0.000000              NaN               1
# 117106    107          0.0   0.000000              NaN               1
# 117123     86          0.0   0.000000              NaN               1
# 117225     87          0.0   0.000000              NaN               1
# 121259    148          0.0   0.002381         0.003367               2
# 121387     70          0.0   0.000000              NaN               1
# 121392     90          0.0   0.000000              NaN               1
# 122189     73          0.0   0.000000              NaN               1
#
#         media_zona  desv_padrao_zona  quantidade_zona  z_score_end  \
# 106223    0.383654          0.120537              138    -1.029911
# 107289    0.166706          0.106301              132          NaN
# 107505    0.319614          0.134063              220          NaN
# 107840    0.176850          0.116654              171          NaN
# 107889    0.176850          0.116654              171          NaN
# 108412    0.179874          0.092873              217          NaN
# 109089    0.281362          0.106799               88    -1.201619
# 110539    0.156064          0.081999               99          NaN
# 110895    0.205158          0.132001               79    -0.865264
# 110912    0.205158          0.132001               79    -0.865264
# 110913    0.205158          0.132001               79          NaN
# 111537    0.168229          0.101614              157          NaN
# 111695    0.173975          0.105777              119          NaN
# 112334    0.326481          0.130530              182          NaN
# 112496    0.191962          0.079746              203          NaN
# 112887    0.321475          0.139014              199          NaN
# 113284    0.243062          0.108478              116          NaN
# 113698    0.353951          0.082758               85    -1.558203
# 113700    0.353951          0.082758               85    -1.558203
# 114185    0.124265          0.061038               97          NaN
# 114825    0.147074          0.065153              119    -0.707107
# 114895    0.130136          0.071522               98          NaN
# 115756    0.147074          0.065153              119    -0.707107
# 115781    0.166270          0.086625              170          NaN
# 115806    0.145068          0.094548              178          NaN
# 115811    0.145068          0.094548              178          NaN
# 115844    0.145068          0.094548              178          NaN
# 116484    0.198312          0.081974              247          NaN
# 116842    0.145068          0.094548              178    -1.148550
# 116843    0.145068          0.094548              178          NaN
# 116853    0.145068          0.094548              178          NaN
# 117020    0.166706          0.106301              132          NaN
# 117022    0.166706          0.106301              132          NaN
# 117035    0.166706          0.106301              132          NaN
# 117096    0.142485          0.069173              149          NaN
# 117106    0.142485          0.069173              149          NaN
# 117123    0.142485          0.069173              149          NaN
# 117225    0.159941          0.086924              165          NaN
# 121259    0.190356          0.106357              106    -0.707107
# 121387    0.198891          0.106933              149          NaN
# 121392    0.198891          0.106933              149          NaN
# 122189    0.160675          0.068283              161          NaN
#
#         z_score_zona
# 106223     -3.182886
# 107289     -1.568243
# 107505     -2.384062
# 107840     -1.516023
# 107889     -1.516023
# 108412     -1.936774
# 109089     -2.634497
# 110539     -1.903249
# 110895     -1.554213
# 110912     -1.554213
# 110913     -1.554213
# 111537     -1.655567
# 111695     -1.644731
# 112334     -2.501195
# 112496     -2.407164
# 112887     -2.312538
# 113284     -2.240655
# 113698     -4.276917
# 113700     -4.276917
# 114185     -2.035851
# 114825     -2.257361
# 114895     -1.819519
# 115756     -2.257361
# 115781     -1.919410
# 115806     -1.534325
# 115811     -1.534325
# 115844     -1.534325
# 116484     -2.419200
# 116842     -1.534325
# 116843     -1.534325
# 116853     -1.534325
# 117020     -1.568243
# 117022     -1.568243
# 117035     -1.568243
# 117096     -2.059836
# 117106     -2.059836
# 117123     -2.059836
# 117225     -1.840021
# 121259     -1.789781
# 121387     -1.859950
# 121392     -1.859950
# 122189     -2.353061

# %% [markdown]
# Analisaremos as zonas 97, 103 e 73

# %% [markdown]
# #### 2.2.2.1 Fernando Falcão, zona 97

# %%
plot_regiao(df_sel, municipio='FERNANDO FALCÃO', zona = 97, normal=True)

# %% [markdown]
# Novamente, analisaremos os endereços da zona 97.

# %%
print("Urnas com menos de 20% de votos para o Bolsonaro")
df_sel[(df_sel.NM_MUNICIPIO == 'FERNANDO FALCÃO') & (df_sel.NR_ZONA == 97) & (df_sel.SG_UF == 'MA') & (df_sel.porcentagem < 0.2)]
# Out:
# Urnas com menos de 20% de votos para o Bolsonaro
#         NR_TURNO SG_UF     NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 110884         2    MA  FERNANDO FALCÃO       97       172
# 110885         2    MA  FERNANDO FALCÃO       97       174
# 110886         2    MA  FERNANDO FALCÃO       97       175
# 110887         2    MA  FERNANDO FALCÃO       97       176
# 110888         2    MA  FERNANDO FALCÃO       97       177
# 110889         2    MA  FERNANDO FALCÃO       97       178
# 110890         2    MA  FERNANDO FALCÃO       97       180
# 110894         2    MA  FERNANDO FALCÃO       97       184
# 110895         2    MA  FERNANDO FALCÃO       97       185
# 110896         2    MA  FERNANDO FALCÃO       97       186
# 110897         2    MA  FERNANDO FALCÃO       97       187
# 110898         2    MA  FERNANDO FALCÃO       97       188
# 110902         2    MA  FERNANDO FALCÃO       97       192
# 110903         2    MA  FERNANDO FALCÃO       97       194
# 110912         2    MA  FERNANDO FALCÃO       97       205
# 110913         2    MA  FERNANDO FALCÃO       97       207
#
#                               DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  \
#
# 110903     -0.759386
# 110912     -1.554213
# 110913     -1.554213

# %%
print("Urnas com mais de 20% de votos para o Bolsonaro")
df_sel[(df_sel.NM_MUNICIPIO == 'FERNANDO FALCÃO') & (df_sel.NR_ZONA == 97) & (df_sel.SG_UF == 'MA') & (df_sel.porcentagem > 0.2)]
# Out:
# Urnas com mais de 20% de votos para o Bolsonaro
#         NR_TURNO SG_UF     NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 110891         2    MA  FERNANDO FALCÃO       97       181
# 110892         2    MA  FERNANDO FALCÃO       97       182
# 110893         2    MA  FERNANDO FALCÃO       97       183
# 110899         2    MA  FERNANDO FALCÃO       97       189
# 110900         2    MA  FERNANDO FALCÃO       97       190
# 110901         2    MA  FERNANDO FALCÃO       97       191
# 110904         2    MA  FERNANDO FALCÃO       97       196
# 110905         2    MA  FERNANDO FALCÃO       97       197
# 110906         2    MA  FERNANDO FALCÃO       97       198
# 110907         2    MA  FERNANDO FALCÃO       97       199
# 110908         2    MA  FERNANDO FALCÃO       97       200
# 110909         2    MA  FERNANDO FALCÃO       97       201
# 110910         2    MA  FERNANDO FALCÃO       97       202
# 110911         2    MA  FERNANDO FALCÃO       97       203
# 110914         2    MA  FERNANDO FALCÃO       97       208
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 110891           POVOADO LEANDRO   131         83    214     0.387850
# 110892           POVOADO LEANDRO   151         78    229     0.340611
# 110893           POVOADO LEANDRO   141         77    218     0.353211
# 110899            POVOADO BURITI   152        101    253     0.399209
# 110900            POVOADO BURITI   156         95    251     0.378486
# 110901            POVOADO BURITI   132        105    237     0.443038
# 110904           RUA EMILIANO SN   161         87    248     0.350806
# 110905           RUA EMILIANO SN   159         83    242     0.342975
# 110906           RUA EMILIANO SN   153         78    231     0.337662
# 110907           RUA EMILIANO SN   139         83    222     0.373874
# 110908           RUA EMILIANO SN   133         86    219     0.392694
# 110909           POVOADO LEANDRO   170        113    283     0.399293
# 110910  AVENIDA ANTONIO LEONTINO   172         98    270     0.362963
# 110911           RUA EMILIANO SN   176         73    249     0.293173
# 110914  AVENIDA ANTONIO LEONTINO   154         79    233     0.339056
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 110891   0.370242         0.027821               4    0.205158
# 110892   0.370242         0.027821               4    0.205158
# 110893   0.370242         0.027821               4    0.205158
# 110899   0.406911         0.032958               3    0.205158
# 110900   0.406911         0.032958               3    0.205158
# 110901   0.406911         0.032958               3    0.205158
# 110904   0.348531         0.034092               6    0.205158
# 110905   0.348531         0.034092               6    0.205158
# 110906   0.348531         0.034092               6    0.205158
# 110907   0.348531         0.034092               6    0.205158
# 110908   0.348531         0.034092               6    0.205158
# 110909   0.370242         0.027821               4    0.205158
# 110910   0.351009         0.016905               2    0.205158
# 110911   0.348531         0.034092               6    0.205158
# 110914   0.351009         0.016905               2    0.205158
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 110891          0.132001               79     0.632931      1.384023
# 110892          0.132001               79    -1.065020      1.026154
# 110893          0.132001               79    -0.612141      1.121606
# 110899          0.132001               79    -0.233682      1.470076
# 110900          0.132001               79    -0.862467      1.313082
# 110901          0.132001               79     1.096149      1.802107
# 110904          0.132001               79     0.066751      1.103389
# 110905          0.132001               79    -0.162958      1.044062
# 110906          0.132001               79    -0.318796      1.003814
# 110907          0.132001               79     0.743372      1.278141
# 110908          0.132001               79     1.295412      1.420717
# 110909          0.132001               79     1.044229      1.470711
# 110910          0.132001               79     0.707107      1.195483
# 110911          0.132001               79    -1.623781      0.666774
# 110914          0.132001               79    -0.707107      1.014370

# %% [markdown]
# As urnas sem voto no Bolsonaro estão todas na ALDEIA ESCALVADO, onde tivemos duas urnas com 0 votos e duas urnas com 1 voto.

# %% [markdown]
# Desta vez, não há uma clara divisão entre porcentagem de votos em aldeias e povoados, porém não há intersecção entre locais com urnas com menos de 20% e urnas com mais de 20% dos votos no Bolsonaro. Fica evidente então que cada local tem uma característica diferente e confirmamos o viés de localização.
#
# Outro ponto a se observar é que todas as urnas com menos de 20% de votos no Bolsonaro estão em aldeias ou povoados.

# %% [markdown]
# #### 2.2.2.2 Montes Altos, zona 103

# %%
plot_regiao(df_sel, municipio='MONTES ALTOS', zona = 103, normal=True)

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'MONTES ALTOS') & (df_sel.NR_ZONA == 103) & (df_sel.SG_UF == 'MA')]
# Out:
#         NR_TURNO SG_UF  NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 113678         2    MA  MONTES ALTOS      103         1
# 113679         2    MA  MONTES ALTOS      103         4
# 113680         2    MA  MONTES ALTOS      103         5
# 113681         2    MA  MONTES ALTOS      103         6
# 113682         2    MA  MONTES ALTOS      103         7
# 113683         2    MA  MONTES ALTOS      103         8
# 113684         2    MA  MONTES ALTOS      103        10
# 113685         2    MA  MONTES ALTOS      103        12
# 113686         2    MA  MONTES ALTOS      103        14
# 113687         2    MA  MONTES ALTOS      103        15
# 113688         2    MA  MONTES ALTOS      103        16
# 113689         2    MA  MONTES ALTOS      103        17
# 113690         2    MA  MONTES ALTOS      103        18
# 113691         2    MA  MONTES ALTOS      103        19
# 113692         2    MA  MONTES ALTOS      103        20
# 113693         2    MA  MONTES ALTOS      103        21
# 113694         2    MA  MONTES ALTOS      103        22
# 113695         2    MA  MONTES ALTOS      103        23
# 113696         2    MA  MONTES ALTOS      103        24
# 113697         2    MA  MONTES ALTOS      103        26
# 113698         2    MA  MONTES ALTOS      103        28
# 113699         2    MA  MONTES ALTOS      103        73
# 113700         2    MA  MONTES ALTOS      103        80
#
#                 DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 113678           AV. FABRÍCIO FERRAZ, S/N   193         94    287
# 113679    RUA PARSONDAS DE CARVALHO, S/N.   146         85    231
# 113680    RUA PARSONDAS DE CARVALHO, S/N.   152         69    221
# 113681              TRAVESSA CENTRAL, S/N   156         69    225
# 113682              TRAVESSA CENTRAL, S/N   170         51    221
# 113683            RUA EUGENIO BARROS, S/N   197         91    288
# 113684            RUA EUGENIO BARROS, S/N   203        107    310
# 113685            RUA EUGENIO BARROS, S/N   199        100    299
# 113686            RUA EUGENIO BARROS, S/N   108         43    151
# 113687  RUA QUINTILIANO JOSE TAVARES, S/N   106         80    186
# 113688     RUA PARSONDAS DE CARVALHO, S/N   175        120    295
# 113689     RUA PARSONDAS DE CARVALHO, S/N   170        115    285
# 113690     RUA PARSONDAS DE CARVALHO, S/N   158        128    286
# 113691     RUA PARSONDAS DE CARVALHO, S/N   164        124    288
# %%
df_sel[(df_sel.NM_MUNICIPIO == 'MONTES ALTOS') & (df_sel.NR_ZONA == 103) & (df_sel.SG_UF == 'MA') & (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA PRINCIPAL, S/N')]
# Out:
#         NR_TURNO SG_UF  NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 113696         2    MA  MONTES ALTOS      103        24
# 113697         2    MA  MONTES ALTOS      103        26
# 113698         2    MA  MONTES ALTOS      103        28
# 113700         2    MA  MONTES ALTOS      103        80
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 113696        RUA PRINCIPAL, S/N    31         21     52     0.403846
# 113697        RUA PRINCIPAL, S/N   159         81    240     0.337500
# 113698        RUA PRINCIPAL, S/N   260          0    260     0.000000
# 113700        RUA PRINCIPAL, S/N   264          0    264     0.000000
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 113696   0.221281          0.14201               9    0.353951
# 113697   0.221281          0.14201               9    0.353951
# 113698   0.221281          0.14201               9    0.353951
# 113700   0.221281          0.14201               9    0.353951
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 113696          0.082758               85     1.285582      0.602904
# 113697          0.082758               85     0.818388     -0.198781
# 113698          0.082758               85    -1.558203     -4.276917
# 113700          0.082758               85    -1.558203     -4.276917

# %% [markdown]
# Verificando o endereço das seções eleitorais 24, 26, 28 e 80 no site https://www.descubraonline.com/eleicoes/, encontramos os seguintes dados:

# %% [markdown]
# ![Captura de tela 2022-11-07 122416.jpg](attachment:bb6db8df-4991-4bb2-beb1-9d3dd5216de0.jpg)

# %% [markdown]
# ![Captura de tela 2022-11-07 122514.jpg](attachment:5dc1ccff-f5cf-41c7-8b6a-37197237b4fa.jpg)

# %% [markdown]
# ![Captura de tela 2022-11-07 122540.jpg](attachment:a8de4870-691d-475c-ae3d-1a42455b72e6.jpg)

# %% [markdown]
# Verificamos então que, apesar de ter o mesmo endereço na tabela do TSE, as seções eleitorais 24 e 26 estão em locais diferentes. As seções 28 e 80 estão no mesmo local (Pô TSE, puxa a orelha do estagiário) e ambas as urnas com 0 votos no Bolsonaro estão neste local, **Aldeia São Jose**.

# %% [markdown]
# Para facilitar a continuação de nossa análise, corrigirei o endereço na tabela do TSE

# %%
df_sel.loc[[113698,113700], 'DS_LOCAL_VOTACAO_ENDERECO'] = 'ALDEIA SAO JOSE'

# %%
df_sel.loc[113697, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'RUA PRINCIPAL, ASSENTAMENTO VALE DO JORDAO'

# %%
df_sel.loc[113696, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'RUA PRINCIPAL, ACAIZAL'

# %% [markdown]
# Removendo as urnas da aldeia São José, temos o seguinte gráfico na zona 103:

# %%
regiao = df_sel[(df_sel.NM_MUNICIPIO == 'MONTES ALTOS') & 
                (df_sel.NR_ZONA == 103) & 
                (df_sel.SG_UF == 'MA') & 
                (~df_sel.NR_SECAO.isin([28,80]))]
plot_regiao(regiao, normal=True)

# %% [markdown]
# As demais urnas da zona 103 não possuem grande discrepância, portanto fica evidente que existe um viés nas urnas da Aldeia São José, onde **todos os eleitores votaram no Lula**.

# %% [markdown]
# #### 2.2.2.3 São Benedito do Rio Preto, zona 73

# %%
plot_regiao(df_sel, municipio='SÃO BENEDITO DO RIO PRETO', zona = 73, normal=True)

# %% [markdown]
# Ao verificar os endereços, encontramos seções em endereços de cidades e endereços em povoados.

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'SÃO BENEDITO DO RIO PRETO') & (df_sel.NR_ZONA == 73) & (df_sel.SG_UF == 'MA')].value_counts('DS_LOCAL_VOTACAO_ENDERECO')
# Out:
# DS_LOCAL_VOTACAO_ENDERECO
# RUA CAPITAO ALMIR MESQUITA                       6
# TRAVESSA MANOEL MESQUITA, S/N                    5
# RUA ACELINO SOUSA, S/N                           4
# RUA FRANCISCO BRAGA DE MESQUITA                  4
# RUA ADÉLIA RABELO                                4
# AVENIDA BRASIL                                   3
# ZONA RURAL                                       3
# POVOADO SÃO JOSÉ DOS COSTAS - ZONA RURAL         2
# RUA JOÃO SOUSA                                   2
# RUA BEIRA CAMPO                                  2
# POVOADO PICOS - ZONA RURAL                       1
# POVOADO BARRA GRANDE - ZONA RURAL                1
# RUA JOSÉ MESQUITA, S/N                           1
# RUA JERÔNIMO FERREIRA                            1
# POVOADO BURITIZAL DOS FLORÊNCIOS - ZONA RURAL    1
# POVOADO COCALZINHO                               1
# POVOADO GUABIRABAL                               1
# POVOADO MARÇAL - ZONA RURAL                      1
# RUA 25 DE MARÇO, S/N                             1
# POVOADO TIBIRIÇÁ - ZONA RURAL                    1
# POVOADO SÃO MIGUEL - ZONA RURAL                  1
# POVOADO BARRA DA AREIA                           1
# POVOADO SANTA MARIA DO VENÂNCIO - ZONA RURAL     1
# POVOADO RIACHÃO DOS CALDAS - ZONA RURAL          1
# POVOADO POEIRÃO - ZONA RURAL                     1
# POVOADO PINDOVAL - ZONA RURAL                    1
# POVOADO LAGOA DA LÚCIA - ZONA RURAL              1
# dtype: int64

# %% [markdown]
# Separando as seções dentro de povoados e fora de povoados, temos as seguintes distribuições:

# %%
regiao_1 = df_sel.loc[df_sel['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("POVOADO", case=False) & 
                              (df_sel.NR_ZONA == 73) & 
                               (df_sel.NM_MUNICIPIO == 'SÃO BENEDITO DO RIO PRETO') &
                                 (df_sel.SG_UF == 'MA')]
regiao_2 = df_sel.loc[~df_sel['DS_LOCAL_VOTACAO_ENDERECO'].str.contains("POVOADO", case=False) & 
                              (df_sel.NR_ZONA == 73) & 
                               (df_sel.NM_MUNICIPIO == 'SÃO BENEDITO DO RIO PRETO')&
                                 (df_sel.SG_UF == 'MA')]

# %%
plot_regiao(regiao_1)

# %%
plot_regiao(regiao_2)

# %% [markdown]
# Entre as seções eleitorais fora de povoados, a distribuição de votos foi razoavelmente consistente.
#
# Entre as seções eleitorais em povoados divemos bastante diferença nos votos.

# %%
regiao_1.sort_values('DS_LOCAL_VOTACAO_ENDERECO')
# Out:
#         NR_TURNO SG_UF               NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 117091         2    MA  SÃO BENEDITO DO RIO PRETO       73        54
# 117123         2    MA  SÃO BENEDITO DO RIO PRETO       73       163
# 117106         2    MA  SÃO BENEDITO DO RIO PRETO       73        98
# 117113         2    MA  SÃO BENEDITO DO RIO PRETO       73       117
# 117112         2    MA  SÃO BENEDITO DO RIO PRETO       73       116
# 117100         2    MA  SÃO BENEDITO DO RIO PRETO       73        83
# 117107         2    MA  SÃO BENEDITO DO RIO PRETO       73       100
# 117096         2    MA  SÃO BENEDITO DO RIO PRETO       73        67
# 117093          0.069173              149     0.707107      2.349675
# 117090          0.069173              149          NaN     -1.298968
# 117094          0.069173              149          NaN     -0.581331

# %% [markdown]
# As seções eleitorais estão todas em povoados distintos. Somente as seções 50 e 63 estão no mesmo povoado, o povoado **São José dos Costas**. Ambas as urnas possuem porcentagem de voto consistentes com sua região.

# %%
print(f"Votos no Lula no povoado São José dos Costas: {202 + 180}")
print(f"Votos no Bolsonaro no povoado São José dos Costas: {65 + 79}")
print("Porcentagem de votos no Bolsonaro no povoado São José dos Costas: {:.2f}%".format( (65 + 79)/(267 + 259)*100))
print("Porcentagem de votos no Bolsonaro na seção 50: {:.2f}%".format(df_sel.loc[117087,'porcentagem']*100))
print("Porcentagem de votos no Bolsonaro na seção 63: {:.2f}%".format(df_sel.loc[117093,'porcentagem']*100))
# Out:
# Votos no Lula no povoado São José dos Costas: 382
# Votos no Bolsonaro no povoado São José dos Costas: 144
# Porcentagem de votos no Bolsonaro no povoado São José dos Costas: 27.38%
# Porcentagem de votos no Bolsonaro na seção 50: 24.34%
# Porcentagem de votos no Bolsonaro na seção 63: 30.50%

# %% [markdown]
# Calcularemos agora, em caso de uma amostragem aleatória de uma binomial com média 27,38%, qual a probabilidade de termos uma urna com 65 votos ou menos para o Bolsonaro de um total de 267 votos.

# %%
print("Probabilidade de urna: {:.2f}%".format( binom.cdf(65,267,0.2738)*100))
# Out:
# Probabilidade de urna: 14.80%

# %% [markdown]
# Podemos dizer então que não se trata de um evento raro, portanto não há evidências de fraude baseado nos votos na urna.

# %% [markdown]
# ### 2.2.3 Verificação Geral

# %% [markdown]
# #### 2.2.3.1 Gráfico geral

# %% [markdown]
# Faremos agora uma verificação geral dos endereços das seções eleitorais sem votos no Bolsonaro.
#
# Votos no mesmo endereço devem ser consistentes com sua localização caso não haja motivo para existir um viés entre duas urnas.

# %%
lista = df_sel[(df_sel.BOLSONARO == 0)]\
[['SG_UF','NM_MUNICIPIO','NR_ZONA','DS_LOCAL_VOTACAO_ENDERECO']]

# %%
locais_index = []
for ind, linha in lista.iterrows():
    locais_index.extend(
        df_sel[(df_sel.SG_UF == linha.SG_UF) & 
               (df_sel.NM_MUNICIPIO == linha.NM_MUNICIPIO) &
               (df_sel.NR_ZONA == linha.NR_ZONA) & 
               (df_sel.DS_LOCAL_VOTACAO_ENDERECO == linha.DS_LOCAL_VOTACAO_ENDERECO)].index.values)

# %%
locais = df_sel.loc[locais_index]

# %%
plot_regiao(locais)

# %% [markdown]
# Nos locais com incidência de urnas sem votos para o Bolsonaro, a maioria das urnas do mesmo local de votação tem menos de 5% de votos no Bolsonaro.
#
# Ainda assim é estatisticamente improvável termos urnas com porcentagens altas de votos no Bolsonaro na mesma região. Verificaremos estes casos.

# %%
locais[locais.porcentagem > 0.6]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 109097         2    MA   CARUTAPERA       55        85
# 109104         2    MA   CARUTAPERA       55        98
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 109097       RUA PRINCIPAL, S/N.    40         74    114     0.649123
# 109104       RUA PRINCIPAL, S/N.    22         83    105     0.790476
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 109097   0.235108         0.195659              21    0.281362
# 109104   0.235108         0.195659              21    0.281362
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 109097          0.106799               88     2.116000      3.443490
# 109104          0.106799               88     2.838447      4.767036

# %% [markdown]
# Novamente temos o endereço **RUA PRINCIPAL, S/N.** um endereço genérico repetido diversas vezes na tabela.

# %% [markdown]
# #### 2.2.3.2 Carutapera

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'CARUTAPERA') &
      (df_sel.NR_ZONA == 55) &
      (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA PRINCIPAL, S/N.')]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 109074         2    MA   CARUTAPERA       55        11
# 109077         2    MA   CARUTAPERA       55        14
# 109078         2    MA   CARUTAPERA       55        15
# 109079         2    MA   CARUTAPERA       55        16
# 109080         2    MA   CARUTAPERA       55        17
# 109081         2    MA   CARUTAPERA       55        18
# 109088         2    MA   CARUTAPERA       55        68
# 109089         2    MA   CARUTAPERA       55        69
# 109090         2    MA   CARUTAPERA       55        70
# 109091         2    MA   CARUTAPERA       55        73
# 109097         2    MA   CARUTAPERA       55        85
# 109100         2    MA   CARUTAPERA       55        91
# 109104         2    MA   CARUTAPERA       55        98
# 109105         2    MA   CARUTAPERA       55        99
# 109114         2    MA   CARUTAPERA       55       123
# 109120         2    MA   CARUTAPERA       55       131
# 109123         2    MA   CARUTAPERA       55       134
# 109124         2    MA   CARUTAPERA       55       135
# 109125         2    MA   CARUTAPERA       55       136
# 109126         2    MA   CARUTAPERA       55       137
# 109127         2    MA   CARUTAPERA       55       138
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 109074       RUA PRINCIPAL, S/N.    39         33     72     0.458333
# 109077       RUA PRINCIPAL, S/N.   124         41    165     0.248485
# 109078       RUA PRINCIPAL, S/N.   173         52    225     0.231111
# 109079       RUA PRINCIPAL, S/N.   166         41    207     0.198068
# 109080       RUA PRINCIPAL, S/N.   202         23    225     0.102222
# 109081       RUA PRINCIPAL, S/N.    92         20    112     0.178571
# 109088       RUA PRINCIPAL, S/N.   200         51    251     0.203187
# 109089       RUA PRINCIPAL, S/N.    53          0     53     0.000000
# 109090       RUA PRINCIPAL, S/N.    44          5     49     0.102041
# 109091       RUA PRINCIPAL, S/N.   205         25    230     0.108696
# 109097       RUA PRINCIPAL, S/N.    40         74    114     0.649123
# 109100       RUA PRINCIPAL, S/N.    79         60    139     0.431655
# 109104       RUA PRINCIPAL, S/N.    22         83    105     0.790476
# 109105       RUA PRINCIPAL, S/N.   111         34    145     0.234483
# 109114       RUA PRINCIPAL, S/N.   155         47    202     0.232673
# 109120       RUA PRINCIPAL, S/N.   198          8    206     0.038835
# 109123       RUA PRINCIPAL, S/N.   191         26    217     0.119816
# 109124       RUA PRINCIPAL, S/N.   239         40    279     0.143369
# 109125       RUA PRINCIPAL, S/N.   105         28    133     0.210526
# 109126       RUA PRINCIPAL, S/N.    90         16    106     0.150943
# 109127       RUA PRINCIPAL, S/N.    77          9     86     0.104651
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
#
 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Praia de São Pedro - Zona Rural'
df_sel.loc[109077, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Estiva - Zona Rural'
df_sel.loc[[109078, 109079, 109114], 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Livramento - Zona Rural'
df_sel.loc[[109080, 109091], 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de São Lourenço - Zona Rural'
df_sel.loc[109081, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'AV. PE. MÁRIO RACCA, S/N.'
df_sel.loc[109088, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Manaus da Beira - Zona Rural'
df_sel.loc[109089, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Murujá - Zona Rural'
df_sel.loc[109090, 'DS_LOCAL_VOTACAO_ENDERECO'] = "Rua Principal, S/n. - Povoado de Olho d'Água dos Marinhos"
df_sel.loc[109097, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Ilha de Fora - Zona Rural'
df_sel.loc[109100, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Canadá - Zona Rural'
df_sel.loc[109104, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Iricuri - Zona Rural'
df_sel.loc[109105, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Açutiua - Zona Rural'
df_sel.loc[109120, 'DS_LOCAL_VOTACAO_ENDERECO'] =  'Rua Principal, S/n. - Povoado de Timbotiua - Zona Rural'
df_sel.loc[109123, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua do Porto, S/n. - Povoado de São Lourenço - Zona Rural'
df_sel.loc[109124, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Forquilha - Zona Rural'
df_sel.loc[109125, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Caju - Zona Rural'
df_sel.loc[109126, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Bajaco - Zona Rural'
df_sel.loc[109127, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal, S/n. - Povoado de Cearazinho - Zona Rural'

# %% [markdown]
# Vamos verificar mais uma vez as urnas:

# %%
lista = df_sel[(df_sel.BOLSONARO == 0)]\
[['SG_UF','NM_MUNICIPIO','NR_ZONA','DS_LOCAL_VOTACAO_ENDERECO']]
locais_index = []
for ind, linha in lista.iterrows():
    locais_index.extend(
        df_sel[(df_sel.SG_UF == linha.SG_UF) & 
               (df_sel.NM_MUNICIPIO == linha.NM_MUNICIPIO) &
               (df_sel.NR_ZONA == linha.NR_ZONA) & 
               (df_sel.DS_LOCAL_VOTACAO_ENDERECO == linha.DS_LOCAL_VOTACAO_ENDERECO)].index.values)
locais = df_sel.loc[locais_index]
plot_regiao(locais)

# %% [markdown]
# Verificaremos agora as seções com mais de 20% de votos no Bolsonaro:

# %%
locais[locais.porcentagem > 0.2]
# Out:
#         NR_TURNO SG_UF          NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 42375          2    BA              SALVADOR        5       447
# 42376          2    BA              SALVADOR        5       448
# 42377          2    BA              SALVADOR        5       449
# 42378          2    BA              SALVADOR        5       450
# 106225         2    MA  AMARANTE DO MARANHÃO       99       129
# 106227         2    MA  AMARANTE DO MARANHÃO       99       133
# 261880         2    PR            ORTIGUEIRA      167        29
# 261894         2    PR            ORTIGUEIRA      167        63
# 468507         2    TO   FORMOSO DO ARAGUAIA       15        64
#
#                            DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 42375   RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   258         76    334
# 42376   RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   255         87    342
# 42377   RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   275         78    353
# 42378   RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   283         72    355
# 106225                                 RUA PRINCIPAL    63         29     92
# 106227                                 RUA PRINCIPAL   114         39    153
# 261880                                 RUA PRINCIPAL   125         93    218
# 261894                                 RUA PRINCIPAL   146         72    218
# 468507                               ILHA DO BANANAL    61         20     81
#
#         porcentagem  media_end  desv_padrao_end  quantidade_end  media_zona  \
# 42375      0.227545   0.183582         0.092265               6    0.260783
# 42376      0.254386   0.183582         0.092265               6    0.260783
# 42377      0.220963   0.183582         0.092265               6    0.260783
# 42378      0.202817   0.183582         0.092265               6    0.260783
# 106225     0.315217   0.141930         0.137808               5    0.383654
# 106227     0.254902   0.141930         0.137808               5    0.383654
# 261880     0.426606   0.192645         0.218185               4    0.434187
# 261894     0.330275   0.192645         0.218185               4    0.434187
# 468507     0.246914   0.127531         0.123658               3    0.509994
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 42375           0.054532              229     0.476480     -0.609512
# 42376           0.054532              229     0.767391     -0.117303
# 42377           0.054532              229     0.405145     -0.730207
# 42378           0.054532              229     0.208470     -1.062972
# 106225          0.120537              138     1.257449     -0.567769
# 106227          0.120537              138     0.819773     -1.068160
# 261880          0.130759               62     1.072306     -0.057977
# 261894          0.130759               62     0.630798     -0.794681
# 468507          0.145876               74     0.965426     -1.803453

# %% [markdown]
# Mais uma vez, vamos checar os locais de votação indicados no site do TSE.

# %% [markdown]
# #### 2.2.3.3 Salvador

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'SALVADOR') &
      (df_sel.NR_ZONA == 5) &
      (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA')]
# Out:
#        NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 42297         2    BA     SALVADOR        5       368
# 42375         2    BA     SALVADOR        5       447
# 42376         2    BA     SALVADOR        5       448
# 42377         2    BA     SALVADOR        5       449
# 42378         2    BA     SALVADOR        5       450
# 42413         2    BA     SALVADOR        5       800
#
#                           DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 42297  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   267         65    332
# 42375  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   258         76    334
# 42376  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   255         87    342
# 42377  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   275         78    353
# 42378  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA   283         72    355
# 42413  RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA    80          0     80
#
#        porcentagem  media_end  desv_padrao_end  quantidade_end  media_zona  \
# 42297     0.195783   0.183582         0.092265               6    0.260783
# 42375     0.227545   0.183582         0.092265               6    0.260783
# 42376     0.254386   0.183582         0.092265               6    0.260783
# 42377     0.220963   0.183582         0.092265               6    0.260783
# 42378     0.202817   0.183582         0.092265               6    0.260783
# 42413     0.000000   0.183582         0.092265               6    0.260783
#
#        desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 42297          0.054532              229     0.132236     -1.191957
# 42375          0.054532              229     0.476480     -0.609512
# 42376          0.054532              229     0.767391     -0.117303
# 42377          0.054532              229     0.405145     -0.730207
# 42378          0.054532              229     0.208470     -1.062972
# 42413          0.054532              229    -1.989721     -4.782211

# %% [markdown]
# Salvador:
# https://www.tre-ba.jus.br/eleitor/titulo-e-local-de-votacao/titulo-e-local-de-votacao

# %% [markdown]
# Todas as seções estão na Rua Direita da Mata Escura, porém, o local de votação não é o mesmo.
#
# As seções 368, 447, 448 ,449 ,450 estão na **ESCOLA MUNICIPAL MAXIMINIANO DA ENCARNAÇÃO**, porém, a seção 800  onde 100% dos votos foram para o Lula está no **CONJUNTO PENAL MASCULINO** e se trata de uma seção prisional. (Quem ainda diz que o Lula ser o mais votado entre os presos é "Fake news"? Vamos ser mais honestos, por favor.)

# %%
df_sel.loc[42413 ,'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua direira da mata escura, S/N - PRISIONAL'

# %%
df_sel_50.loc[42413 ,'DS_LOCAL_VOTACAO_ENDERECO']
# Out:
# 'RUA DIRETA DA MATA ESCURA, S/N - ZONA URBANA'

# %% [markdown]
# Agora verificaremos o município Amarante do Maranhão

# %% [markdown]
# #### 2.2.3.4 Amarante do Maranhão

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'AMARANTE DO MARANHÃO') &
      (df_sel.NR_ZONA == 99) &
      (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA PRINCIPAL')]
# Out:
#         NR_TURNO SG_UF          NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 106223         2    MA  AMARANTE DO MARANHÃO       99       127
# 106225         2    MA  AMARANTE DO MARANHÃO       99       129
# 106226         2    MA  AMARANTE DO MARANHÃO       99       130
# 106227         2    MA  AMARANTE DO MARANHÃO       99       133
# 106230         2    MA  AMARANTE DO MARANHÃO       99       136
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 106223             RUA PRINCIPAL    73          0     73     0.000000
# 106225             RUA PRINCIPAL    63         29     92     0.315217
# 106226             RUA PRINCIPAL   115          4    119     0.033613
# 106227             RUA PRINCIPAL   114         39    153     0.254902
# 106230             RUA PRINCIPAL   287         34    321     0.105919
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 106223    0.14193         0.137808               5    0.383654
# 106225    0.14193         0.137808               5    0.383654
# 106226    0.14193         0.137808               5    0.383654
# 106227    0.14193         0.137808               5    0.383654
# 106230    0.14193         0.137808               5    0.383654
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 106223          0.120537              138    -1.029911     -3.182886
# 106225          0.120537              138     1.257449     -0.567769
# 106226          0.120537              138    -0.785997     -2.904021
# 106227          0.120537              138     0.819773     -1.068160
# 106230          0.120537              138    -0.261315     -2.304157

# %% [markdown]
# Checando as localizações pelo site, temos:
# - Seção 127 - Rua Principal - Aldeia Canudal
# - Seção 129 - Rua Principal - Aldeia Arariboia
# - Seção 130 - Rua Principal - Aldeia Cigana
# - Seção 133 - Rua Principal - Assentamento Curitiba
# - Seção 136 - Rua Principal - Aldeia Juçaral

# %%
df_sel.loc[106223, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Aldeia Canudal'
df_sel.loc[106225, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Aldeia Arariboia'
df_sel.loc[106226, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Aldeia Cigana'
df_sel.loc[106227, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Assentamento Curitiba'
df_sel.loc[106230, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Aldeia Juçaral'

# %% [markdown]
# #### 2.2.3.5 Ortigueira

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'ORTIGUEIRA') &
      (df_sel.NR_ZONA == 167) &
      (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA PRINCIPAL')]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 261880         2    PR   ORTIGUEIRA      167        29
# 261894         2    PR   ORTIGUEIRA      167        63
# 261915         2    PR   ORTIGUEIRA      167        96
# 261917         2    PR   ORTIGUEIRA      167        99
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 261880             RUA PRINCIPAL   125         93    218     0.426606
# 261894             RUA PRINCIPAL   146         72    218     0.330275
# 261915             RUA PRINCIPAL   223          0    223     0.000000
# 261917             RUA PRINCIPAL   216          3    219     0.013699
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 261880   0.192645         0.218185               4    0.434187
# 261894   0.192645         0.218185               4    0.434187
# 261915   0.192645         0.218185               4    0.434187
# 261917   0.192645         0.218185               4    0.434187
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 261880          0.130759               62     1.072306     -0.057977
# 261894          0.130759               62     0.630798     -0.794681
# 261915          0.130759               62    -0.882944     -3.320520
# 261917          0.130759               62    -0.820160     -3.215757

# %% [markdown]
# Verificando os endereços através do site https://www.diariocidade.com/pr/ortigueira/enderecos/, temos:
#
# - Seção 29: Rua Principal - Lageado Seco
# - Seção 63: Estrada Banhadão/briolândia S/n
# - Seção 99: Rua principal - Comunidade Maila Sabrina
#
# Por hora deixarei em aberto a seção 96, pois não consegui maiores informações do endereço desta seção. (Pô Paraná, é muito difícil acessar seus dados!)

# %%
df_sel.loc[261880, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal - Lageado Seco'
df_sel.loc[261894, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Estrada Banhadão/briolândia S/n'
df_sel.loc[261917, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua principal - Comunidade Maila Sabrina'

# %% [markdown]
# #### 2.2.3.6 Formoso do Araguaia

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'FORMOSO DO ARAGUAIA') &
      (df_sel.NR_ZONA == 15) &
      (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'ILHA DO BANANAL')]
# Out:
#         NR_TURNO SG_UF         NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 468507         2    TO  FORMOSO DO ARAGUAIA       15        64
# 468508         2    TO  FORMOSO DO ARAGUAIA       15        65
# 468512         2    TO  FORMOSO DO ARAGUAIA       15        72
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 468507           ILHA DO BANANAL    61         20     81     0.246914
# 468508           ILHA DO BANANAL   172         27    199     0.135678
# 468512           ILHA DO BANANAL    97          0     97     0.000000
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 468507   0.127531         0.123658               3    0.509994
# 468508   0.127531         0.123658               3    0.509994
# 468512   0.127531         0.123658               3    0.509994
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 468507          0.145876               74     0.965426     -1.803453
# 468508          0.145876               74     0.065889     -2.565986
# 468512          0.145876               74    -1.031315     -3.496080

# %% [markdown]
# Conferindo os endereços através do site https://www.tre-to.jus.br/eleicoes/eleicoes-suplementares-1/locais-de-votacao

# %% [markdown]
# - Seção 64: ALDEIA TXUIRÍ
# - Seção 65: ALDEIA CANOANÃ
# - Seção 72: ALDEIA SÃO JOÃO

# %%
df_sel.loc[468507, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'ALDEIA TXUIRÍ'
df_sel.loc[468508, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'ALDEIA CANOANÃ'
df_sel.loc[468512, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'ALDEIA SÃO JOÃO'

# %% [markdown]
# Vamos conferir todos os endereços novamente:

# %%
lista = df_sel[(df_sel.BOLSONARO == 0)]\
[['SG_UF','NM_MUNICIPIO','NR_ZONA','DS_LOCAL_VOTACAO_ENDERECO']]
locais_index = []
for ind, linha in lista.iterrows():
    locais_index.extend(
        df_sel[(df_sel.SG_UF == linha.SG_UF) & 
               (df_sel.NM_MUNICIPIO == linha.NM_MUNICIPIO) &
               (df_sel.NR_ZONA == linha.NR_ZONA) & 
               (df_sel.DS_LOCAL_VOTACAO_ENDERECO == linha.DS_LOCAL_VOTACAO_ENDERECO)].index.values)
locais = df_sel.loc[locais_index]
plot_regiao(locais)

# %% [markdown]
# Vamos continuar verificando as urnas com mais de 6% de votos no Bolsonaro

# %% [markdown]
# #### 2.2.3.7 Santo Amaro do Maranhão

# %%
locais[locais.porcentagem > 0.06]
# Out:
#         NR_TURNO SG_UF             NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 116840         2    MA  SANTO AMARO DO MARANHÃO       32       131
# 116841         2    MA  SANTO AMARO DO MARANHÃO       32       132
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 116840         RUA PRINCIPAL S/N   171         15    186     0.080645
# 116841         RUA PRINCIPAL S/N    90          9     99     0.090909
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 116840   0.057185         0.049789               3    0.145068
# 116841   0.057185         0.049789               3    0.145068
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 116840          0.094548              178      0.47120     -0.681375
# 116841          0.094548              178      0.67735     -0.572817

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'SANTO AMARO DO MARANHÃO') & (df_sel.DS_LOCAL_VOTACAO_ENDERECO == 'RUA PRINCIPAL S/N')]
# Out:
#         NR_TURNO SG_UF             NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 116840         2    MA  SANTO AMARO DO MARANHÃO       32       131
# 116841         2    MA  SANTO AMARO DO MARANHÃO       32       132
# 116842         2    MA  SANTO AMARO DO MARANHÃO       32       133
#
#        DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 116840         RUA PRINCIPAL S/N   171         15    186     0.080645
# 116841         RUA PRINCIPAL S/N    90          9     99     0.090909
# 116842         RUA PRINCIPAL S/N    83          0     83     0.000000
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 116840   0.057185         0.049789               3    0.145068
# 116841   0.057185         0.049789               3    0.145068
# 116842   0.057185         0.049789               3    0.145068
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 116840          0.094548              178      0.47120     -0.681375
# 116841          0.094548              178      0.67735     -0.572817
# 116842          0.094548              178     -1.14855     -1.534325

# %% [markdown]
# - Seção 131: Rua Principal S/n - Povoado Pães
# - Seção 132: Rua Principal S/n - Povoado Buriti
# - Seção 133: Rua Principal S/n - Povoado Lavado

# %%
df_sel.loc[116840, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal S/n - Povoado Pães'
df_sel.loc[116841, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal S/n - Povoado Buriti'
df_sel.loc[116842, 'DS_LOCAL_VOTACAO_ENDERECO'] = 'Rua Principal S/n - Povoado Lavado'

# %%
lista = df_sel[(df_sel.BOLSONARO == 0)]\
[['SG_UF','NM_MUNICIPIO','NR_ZONA','DS_LOCAL_VOTACAO_ENDERECO']]
locais_index = []
for ind, linha in lista.iterrows():
    locais_index.extend(
        df_sel[(df_sel.SG_UF == linha.SG_UF) & 
               (df_sel.NM_MUNICIPIO == linha.NM_MUNICIPIO) &
               (df_sel.NR_ZONA == linha.NR_ZONA) & 
               (df_sel.DS_LOCAL_VOTACAO_ENDERECO == linha.DS_LOCAL_VOTACAO_ENDERECO)].index.values)
locais = df_sel.loc[locais_index]
plot_regiao(locais)

# %% [markdown]
# Com este gráfico, eliminamos por completo as dúvidas em relação às "urnas impossíveis".
#
# **As urnas sem votos no Bolsonaro estão em locais onde o Lula vence por unanimidade**

# %% [markdown]
# ## 2.3 - Outras zonas eleitorais com urnas suspeitas.

# %% [markdown]
# ### 2.3.1 Visão Geral

# %% [markdown]
# Apesar de eliminarmos as dúvidas comparando as urnas em um mesmo local de votação, algumas zonas eleitorais ainda levantaram suspeitas.
#
# Em zonas eleitorais em grandes cidades é difícil de se justificar uma urna sem votos para o Bolsonaro, mesmo não sendo o mesmo local de votação. Analisaremos então alguns destes casos.

# %%
# Quantidade de urnas estatisticamente improváveis em sua zona eleitoral
df_sel[(df_sel.BOLSONARO == 0) ].groupby('SG_UF')['NM_MUNICIPIO'].count().reset_index(name="Urnas sem votos para o Bolsonaro")
# Out:
#    SG_UF  Urnas sem votos para o Bolsonaro
# 0     AC                                 2
# 1     AM                                23
# 2     BA                                19
# 3     CE                                 8
# 4     MA                                47
# 5     MG                                 9
# 6     MS                                 1
# 7     MT                                 5
# 8     PA                                 8
# 9     PI                                 7
# 10    PR                                 1
# 11    RR                                 2
# 12    RS                                 2
# 13    SC                                 1
# 14    SE                                 1
# 15    SP                                 4
# 16    TO                                 1
# 17    ZZ                                 3

# %% [markdown]
# ### 2.3.2 Mato Grosso

# %%
df_sel[(df_sel.BOLSONARO == 0) & (df_sel.SG_UF == 'MT')]
# Out:
#         NR_TURNO SG_UF           NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 179832         2    MT           CAMPINÁPOLIS       26       189
# 180440         2    MT               CONFRESA       28       158
# 183685         2    MT     PEIXOTO DE AZEVEDO       33       255
# 183949         2    MT  PORTO ALEGRE DO NORTE       28       191
# 184899         2    MT        SANTA TEREZINHA       16        86
#
#                                 DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  \
# 179832                 ALDEIA INDÍGENA ALDEIONA - ÂNHIUDU   265          0
# 180440                       ALDEIA INDÍGENA URUBU BRANCO   383          0
# 183685  LAT S 10 GRAUS 20 MIN 20.8 SEG E LONG W 053 GR...   116          0
# 183949                             ALDEIA INDÍGENA SAPEVA    55          0
# 184899                                      ALDEIA ITXALÁ   248          0
#
#         total  porcentagem  media_end  desv_padrao_end  quantidade_end  \
# 179832    265          0.0   0.006148         0.008694               2
# 180440    383          0.0   0.000000              NaN               1
# 183685    116          0.0   0.000000              NaN               1
# 183949     55          0.0   0.000000              NaN               1
# 184899    248          0.0   0.000000              NaN               1
#
#         media_zona  desv_padrao_zona  quantidade_zona  z_score_end  \
# 179832    0.607867          0.185383               95    -0.707107
# 180440    0.659319          0.132438              115          NaN
# 183685    0.637793          0.120952              166          NaN
# 183949    0.659319          0.132438              115          NaN
# 184899    0.624792          0.144282               75          NaN
#
#         z_score_zona
# 179832     -3.278973
# 180440     -4.978317
# 183685     -5.273131
# 183949     -4.978317
# 184899     -4.330350

# %% [markdown]
# No caso do Mato Grosso, os endereços estão em aldeias indígenas ou em um local sem nome de rua, onde o endereço foi dado através de latitude e longitude.

# %% [markdown]
# ### 2.3.3 São Paulo

# %%
df_sel[(df_sel.BOLSONARO == 0) & (df_sel.SG_UF == 'SP')]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 386442         2    SP       FRANCA      291       341
# 389587         2    SP    GUARULHOS      185       372
# 404490         2    SP         MAUÁ      217       353
# 409797         2    SP       OSASCO      315       336
#
#                                 DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  \
# 386442                    AV. SIDNEY ROMEU DE ANDRADE S/N    14          0
# 389587                        RUA MINISTRO HIPÓLITO, 3650    10          0
# 404490                      AVENIDA PAPA JOÃO XXIII, 3905    32          0
# 409797  RODOVIA RAPOSO TAVARES, KM 20 -CONT. VIADUTO S...    89          0
#
#         total  porcentagem  media_end  desv_padrao_end  quantidade_end  \
# 386442     14          0.0        0.0              NaN               1
# 389587     10          0.0        0.0              NaN               1
# 404490     32          0.0        0.0              NaN               1
# 409797     89          0.0        0.0              NaN               1
#
#         media_zona  desv_padrao_zona  quantidade_zona  z_score_end  \
# 386442    0.621277          0.061673              375          NaN
# 389587    0.439384          0.050294              414          NaN
# 404490    0.505837          0.062449              271          NaN
# 409797    0.487792          0.065929              365          NaN
#
#         z_score_zona
# 386442    -10.073647
# 389587     -8.736304
# 404490     -8.099998
# 409797     -7.398736

# %% [markdown]
# #### 2.3.3.1 Osasco

# %%
plot_regiao(df_sel, municipio = 'OSASCO', uf = 'SP', normal = True)

# %% [markdown]
# Em Osasco, uma única urna teve 0 votos para o Bolsonaro.

# %% [markdown]
# Apenas observando o endereço é difícil de entender o motivo de uma urna em uma área urbana ter um alto grau de viés.
#
# Através o CSV dos locais de votação em São Paulo, disponível no site do TSE, podemos adquirir mais informações sobre esta seção eleitoral:
#
# https://www.tre-sp.jus.br/eleitor/atendimento-online/titulo-e-local-de-votacao/consulta-por-zona-eleitoral-e-bairro

# %% [markdown]
# - Seção 336: CENTRO DE DETENÇÃO PROVISÓRIA OSASCO I

# %% [markdown]
# Mais uma vez, esta seção eleitoral se trata de uma **seção prisional**. Há então um viés indiscutível em relação às outras urnas de Osasco.

# %% [markdown]
# #### 2.3.3.4 Mauá

# %% [markdown]
# Em Mauá tivemos uma urna com 0 votos para o Bolsonaro, tendo apenas 32 votos.

# %%
plot_regiao(df_sel, municipio = 'MAUÁ', uf = 'SP', normal = True)

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'MAUÁ') & (df_sel.porcentagem < 0.1)]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 404490         2    SP         MAUÁ      217       353
#
#             DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 404490  AVENIDA PAPA JOÃO XXIII, 3905    32          0     32          0.0
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 404490        0.0              NaN               1    0.505837
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 404490          0.062449              271          NaN     -8.099998

# %% [markdown]
# A seção 353 fica no CENTRO DE DETENÇÃO PROVISÓRIA DE MAUÁ, AVENIDA PAPA JOÃO XXIII.

# %% [markdown]
# #### 2.3.3.5 Guarulhos

# %%
plot_regiao(df_sel, municipio = 'GUARULHOS', uf = 'SP', normal = True)

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'GUARULHOS') & (df_sel.BOLSONARO == 0)]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 389587         2    SP    GUARULHOS      185       372
#
#           DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 389587  RUA MINISTRO HIPÓLITO, 3650    10          0     10          0.0
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 389587        0.0              NaN               1    0.439384
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 389587          0.050294              414          NaN     -8.736304

# %% [markdown]
# A seção 353 fica na FUNDAÇÃO CASA GUARULHOS.

# %% [markdown]
# #### 2.3.3.6 Franca

# %%
plot_regiao(df_sel, municipio = 'FRANCA', uf = 'SP', normal = True)

# %%
df_sel[(df_sel.NM_MUNICIPIO == 'FRANCA') & (df_sel.BOLSONARO == 0)]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 386442         2    SP       FRANCA      291       341
#
#               DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 386442  AV. SIDNEY ROMEU DE ANDRADE S/N    14          0     14          0.0
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 386442        0.0              NaN               1    0.621277
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 386442          0.061673              375          NaN    -10.073647

# %% [markdown]
# A seção 353 fica na PENITENCIÁRIA  DE FRANCA","AV. SIDNEY ROMEU DE ANDRADE S/N"

# %% [markdown]
# Deste modo, identificamos que todas as urnas com 0 votos para o Bolsonaro estão em penitenciárias ou an fundação casa.

# %% [markdown]
# ### 2.3.3.7 Outras regiões

# %%
local='TREMEMBÉ'
plot_regiao(df_sel, municipio =local, uf='SP')

# %%
df_sel[(df_sel.NM_MUNICIPIO == local) & (df_sel.SG_UF == 'SP') & (df_sel.porcentagem < 0.05)]
# Out:
#         NR_TURNO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 464648         2    SP     TREMEMBÉ      314       172
#
#                     DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 464648  RODOVIA AMADOR BUENO DA VEIGA, KM 140    87          3     90
#
#         porcentagem  media_end  desv_padrao_end  quantidade_end  media_zona  \
# 464648     0.033333   0.033333              NaN               1    0.629365
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 464648          0.078215              149          NaN     -7.620382

# %% [markdown]
# - Zona 314, Seção 172: PENITENCIÁRIA I DR TARCIZO LEONCE PINHEIRO CINTRA DE TREMEMBÉ, RODOVIA AMADOR BUENO DA VEIGA, KM 140

# %%
local='CERQUEIRA CÉSAR'
plot_regiao(df_sel, municipio =local, uf='SP')

# %%
df_sel[(df_sel.NM_MUNICIPIO == local) & (df_sel.SG_UF == 'SP') & (df_sel.porcentagem < 0.05)]
# Out:
#         NR_TURNO SG_UF     NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 380672         2    SP  CERQUEIRA CÉSAR      205        79
#
#                    DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 380672  RODOVIA SALIN ANTONIO CURIATI, KM 21   101          4    105
#
#         porcentagem  media_end  desv_padrao_end  quantidade_end  media_zona  \
# 380672     0.038095   0.038095              NaN               1    0.562555
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 380672           0.12948               77          NaN     -4.050492

# %% [markdown]
# - Zona 205, seção 79: CENTRO DE DETENÇÃO PROVISÓRIA  DE CERQUEIRA CÉSAR, RODOVIA SALIN ANTONIO CURIATI, KM 21

# %%
local='ITAPECERICA DA SERRA'
plot_regiao(df_sel, municipio =local, uf='SP')

# %%
df_sel[(df_sel.NM_MUNICIPIO == local) & (df_sel.SG_UF == 'SP') & (df_sel.porcentagem < 0.05)]
# Out:
#         NR_TURNO SG_UF          NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 394722         2    SP  ITAPECERICA DA SERRA      201       476
#
#                      DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  \
# 394722  ESTRADA MUNICIPAL FERREIRA GUEDES, 405    49          2     51
#
#         porcentagem  media_end  desv_padrao_end  quantidade_end  media_zona  \
# 394722     0.039216   0.039216              NaN               1    0.446624
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 394722          0.081174              452          NaN     -5.018957

# %% [markdown]
# - Zona 201, seção 476: CENTRO DE DETENÇÃO PROVISÓRIA ASP NILTON CELESTINO, ESTRADA MUNICIPAL FERREIRA GUEDES, 405

# %%
local='CARAGUATATUBA'
plot_regiao(df_sel, municipio =local, uf='SP')

# %%
df_sel[(df_sel.NM_MUNICIPIO == local) & (df_sel.SG_UF == 'SP') & (df_sel.porcentagem < 0.05)]
# Out:
#         NR_TURNO SG_UF   NM_MUNICIPIO  NR_ZONA  NR_SECAO  \
# 379008         2    SP  CARAGUATATUBA      206       237
#
#            DS_LOCAL_VOTACAO_ENDERECO  LULA  BOLSONARO  total  porcentagem  \
# 379008  ESTRADA DO PIRASSUNUNGA, 500   134          7    141     0.049645
#
#         media_end  desv_padrao_end  quantidade_end  media_zona  \
# 379008   0.050558         0.001291               2    0.593216
#
#         desv_padrao_zona  quantidade_zona  z_score_end  z_score_zona
# 379008          0.072769              357    -0.707107      -7.46977

# %% [markdown]
# - Zona 206, seção 237: CENTRO DE DETENÇÃO PROVISÓRIA DE CARAGUATATUBA, ESTRADA DO PIRASSUNUNGA

# %% [markdown]
# # 3 - Conclusão

# %% [markdown]
# As urnas que foram consideradas estatisticamente impossíveis de ocorrer aleatoriamente são facilmente justificáveis pelo auto grau de viés gerado pelo grupo de eleitores da seção eleitoral.
#
# No estado de São Paulo tivemos 4 urnas sem votos para o Bolsonaro. Todas as urnas eram exclusivas para presos provisórios ou para adolescentes da Fundação Casa. O mesmo padrão foi encontrado em outros estados.
#
# No Amazonas tivemos urnas com 60% e com 0% de votos para o Bolsonaro na mesma região. A urna com 60% estava no **pelotão de fronteira estirão do Equador**, enquanto as urnas com 0% estavam em **aldeias**, novamente separando grupos com alto grau de viés político.
#
# Em nossa análise não foi encontrada nenhuma seção eleitoral discrepante sem justificativa para a existência de um viés. Os casos que não foram analisados representam uma porcentagem muito baixa para ter qualquer relevância no resultado final.
